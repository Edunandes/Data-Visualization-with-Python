# %% [markdown]
# ## Libraries

# %%
import pandas as pd # library for data manipulation
import matplotlib.pyplot as plt # library for visualization
import seaborn as sns # library for visualization
sns.set() # this command sets the seaborn chart style as the default

# %% [markdown]
# ## Pie Chart

# %%
#load data set
df_fuel_engine_type = pd.read_csv("pie_chart_data.csv")
df_fuel_engine_type
# Out:
#   Engine Fuel Type  Number of Cars
# 0           Diesel            2019
# 1              Gas             613
# 2            Other             154
# 3           Petrol            1559

# %%
#raw pie chart 

plt.figure(figsize = (10, 8))

plt.pie(df_fuel_engine_type['Number of Cars'],
       labels = df_fuel_engine_type['Engine Fuel Type'].values,
       autopct = '%.2f%%')

plt.show()

# %%
sns.set_palette('colorblind')

# %%
#Improve Pie Chart 

plt. figure(figsize = (10, 8))

plt.pie(df_fuel_engine_type['Number of Cars'], 
       labels = df_fuel_engine_type['Engine Fuel Type'].values,
       autopct = '%.2f%%', textprops = {'size':'large', 'fontweight':'bold', 'rotation':30, 'color':'white'}
              )

plt.axis('equal') 
plt.legend(loc='lower left', fontsize = 10)

plt.title('Cars by Engine Fuel Type', fontsize= 18, fontweight = 'bold')
plt.savefig("Cars-by-Engine-Fuel-Type-Pie-Chart.png")
plt.show()
