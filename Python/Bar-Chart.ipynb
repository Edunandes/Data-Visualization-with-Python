# %% [markdown]
# ## Libraries

# %%
import pandas as pd # library for data manipulation
import matplotlib.pyplot as plt # library for visualization
import seaborn as sns # library for visualization
sns.set() # this command sets the seaborn chart style as the default

from matplotlib.ticker import PercentFormatter #converts values into percentage format

# %% [markdown]
# ## Bar Chart

# %%
# load the file 
df_used_cars = pd.read_csv('bar_chart_data.csv')
df_used_cars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
#Plot the bar chart 
plt.bar(x = df_used_cars["Brand"], height = df_used_cars["Cars Listings"])
plt.show()

# %%
#Optimize for a better visualization 

plt.figure(figsize = (9, 6))
plt.bar(x = df_used_cars["Brand"], height = df_used_cars["Cars Listings"],
        color = "midnightblue")

plt.title("Cars Listings by Brand", fontsize = 16, fontweight = "bold")
plt.ylabel("Numbers of Listings", fontsize = 13)

plt.xticks(rotation = 45, fontsize = 13) 
plt.yticks(fontsize = 13) 

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, int(yval), ha='center', va='bottom', 
             fontsize=12, fontweight='bold')

plt.tight_layout()

plt.savefig("Used Cars Bar.png", dpi = 300)
plt.show()

# %%
#Bar Chart Horizontal 

plt.figure(figsize = (9, 6))
plt.barh(y = df_used_cars["Brand"], 
         width = df_used_cars["Cars Listings"],
        color = "midnightblue")

plt.title("Cars Listings by Brand", fontsize = 16, fontweight = "bold")
plt.xlabel("Numbers of Listings", fontsize = 13)

plt.xticks(fontsize = 13) 
plt.yticks(fontsize = 13) 

for bar in bars:
    xval = bar.get_width()
    plt.text(xval, bar.get_y() + bar.get_height()/2, int(xval), va='center', ha='left',
             fontsize=12, fontweight='bold')


plt.tight_layout()

plt.savefig("Used Cars Bar Horizontal.png")
plt.show()
